# %%
import pandas as pd

def getDataset(path):
    return pd.read_csv(path, sep='|', header=None, names=['image_id', 'question', 'answer'])

# %%
df = getDataset(r"F:\Research\Implementation\Dataset\ImageClef-2019-VQA-Med-Training\QAPairsByCategory\C1_Modality_train.txt")
df
# Out:
#          image_id                                           question  \
# 0     synpic41148                        what kind of image is this?
# 1     synpic43984                       is this a t1 weighted image?
# 2     synpic38930  what type of imaging modality is used to acqui...
# 3     synpic52143                         is this a noncontrast mri?
# 4     synpic20934               what type of image modality is this?
# ...           ...                                                ...
# 3195  synpic35685                       is this a t2 weighted image?
# 3196  synpic35687                       is this a t2 weighted image?
# 3197  synpic35701  what imaging modality was used to take this im...
# 3198  synpic48036                          is this a noncontrast ct?
# 3199  synpic54897                                 is this a ct scan?
#
#                       answer
# 0       cta - ct angiography
# 1                         no
# 2            us - ultrasound
# ...

# %%
print("The total Number of classes in 'Modality Dataset' : ",len(df['answer'].unique()))
# Out:
# The total Number of classes in 'Modality Dataset' :  44

# %%
df = getDataset(r"F:\Research\Implementation\Dataset\ImageClef-2019-VQA-Med-Training\QAPairsByCategory\C2_Plane_train.txt")
df
# Out:
#          image_id                              question        answer
# 0     synpic41148      which plane is this image taken?         axial
# 1     synpic43984      which plane is this image taken?         axial
# 2     synpic38930     what plane is this ultrasound in?  longitudinal
# 3     synpic52143    which plane is the image shown in?       coronal
# 4     synpic20934          in what plane is this x-ray?       lateral
# ...           ...                                   ...           ...
# 3195  synpic35685            in what plane is this mri?      sagittal
# 3196  synpic35687         which plane is this image in?      sagittal
# 3197  synpic35701       what is the plane of the image?      sagittal
# 3198  synpic48036  what imaging plane is depicted here?         axial
# 3199  synpic54897      what plane was used in this mri?      sagittal
#
# [3200 rows x 3 columns]

# %%
print("The total Number of classes in 'Plane Dataset' : ",len(df['answer'].unique()))
# Out:
# The total Number of classes in 'Plane Dataset' :  15

# %%
df = getDataset(r"F:\Research\Implementation\Dataset\ImageClef-2019-VQA-Med-Training\QAPairsByCategory\C3_Organ_train.txt")
df
# Out:
#          image_id                                           question  \
# 0     synpic41148           which organ is captured by this ct scan?
# 1     synpic43984  what organ system is primarily present in this...
# 2     synpic38930                      which organ system is imaged?
# 3     synpic52143                   the mri shows what organ system?
# 4     synpic20934          what organ system is shown in this x-ray?
# ...           ...                                                ...
# 3195  synpic35685                    what organ is this mri showing?
# 3196  synpic35687           what organ system is shown in the image?
# 3197  synpic35701        what organ system is displayed in this mri?
# 3198  synpic48036        which organ system is shown in the ct scan?
# 3199  synpic54897        what organ system is displayed in this mri?
#
#                          answer
# 0     lung, mediastinum, pleura
# 1            skull and contents
# 2                 genitourinary
# ...

# %%
print("The total Number of classes in 'Organ Dataset' : ",len(df['answer'].unique()))
# Out:
# The total Number of classes in 'Organ Dataset' :  10

# %%
df = getDataset(r"F:\Research\Implementation\Dataset\ImageClef-2019-VQA-Med-Training\QAPairsByCategory\C4_Abnormality_train.txt")
df
# Out:
#          image_id                                        question  \
# 0     synpic41148                what is abnormal in the ct scan?
# 1     synpic43984          what abnormality is seen in the image?
# 2     synpic38930  what is the primary abnormality in this image?
# 3     synpic52143  what is the primary abnormality in this image?
# 4     synpic20934  what is the primary abnormality in this image?
# ...           ...                                             ...
# 3187  synpic35685                           is this image normal?
# 3188  synpic35687          is there something wrong in the image?
# 3189  synpic35701         is there evidence of any abnormalities?
# 3190  synpic48036                          is the ct scan normal?
# 3191  synpic54897             is there an abnormality in the mri?
#
#                                                  answer
# 0     cryptococcal pneumonia in an immunocompetent host
# 1                      arteriovenous malformation (avm)
# ...

# %%
print("The total Number of classes in 'Abnormality Dataset' : ",len(df['answer'].unique()))
# Out:
# The total Number of classes in 'Abnormality Dataset' :  1485
